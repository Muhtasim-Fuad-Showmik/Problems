# %% [markdown]
# # Problem: Customers Who Never Order
#
# [Leetcode](https://leetcode.com/problems/customers-who-never-order/description/)
#
# Table: `Customers`
#
# ```
# +-------------+---------+
# | Column Name | Type    |
# +-------------+---------+
# | id          | int     |
# | name        | varchar |
# +-------------+---------+
# id is the primary key (column with unique values) for this table.
# Each row of this table indicates the ID and name of a customer.
# ```
#
# Table: `Orders`
#
# ```
# +-------------+------+
# | Column Name | Type |
# +-------------+------+
# | id          | int  |
# | customerId  | int  |
# +-------------+------+
# id is the primary key (column with unique values) for this table.
# customerId is a foreign key (reference columns) of the ID from the Customers table.
# Each row of this table indicates the ID of an order and the ID of the customer who ordered it.
# ```
#
# Write a solution to find all customers who never order anything.\
# Return the result table in **any order**.\
# The result format is in the following example.
#
# ## Example 1:
#
# **Input:**
# ```
# Customers table:
# +----+-------+
# | id | name  |
# +----+-------+
# | 1  | Joe   |
# | 2  | Henry |
# | 3  | Sam   |
# | 4  | Max   |
# +----+-------+
# Orders table:
# +----+------------+
# | id | customerId |
# +----+------------+
# | 1  | 3          |
# | 2  | 1          |
# +----+------------+
# ```
# **Output:**
# ```
# +-----------+
# | Customers |
# +-----------+
# | Henry     |
# | Max       |
# +-----------+
# ```

# %% [markdown]
# # Solution
#
# ## Intuition (Accepted)
#
# The solution to the problem comes from retrieving all records from the table `Customers` with the table `Orders` left joined on to it, and then filtering out the data from the joined table by displaying only the records that have _undefined_ records joined from the `Orders` table that would appear as `NULL` in the joined table.
#
# ## Approach
#
# **Selection** for the solution includes the following fields (as demonstrated in the provided example):
# - `Customers` -> `name` _renamed as_ `Customers`
#
# **Data source** for the selection of data would be the `Customers` table with the `Orders` table left joined into it on the following condition:
# - $ Orders.customerId = Customers.id $ from the defined association between the two tables.
#
# **Conditions** to meet for the selection has to be:
# - `Orders.customerId IS NULL` as we only want **customers** who never order, and therefore have _no orders_, meaning on a left join their **Orders** fields would appear as `NULL`.
#
# ### Code
#
# ```sql
# SELECT
#     Customers.name AS Customers
# FROM
#     Customers
# LEFT JOIN
#     Orders
# ON
#     Orders.customerId = Customers.id
# WHERE
#     Orders.customerId IS NULL;
# ```
